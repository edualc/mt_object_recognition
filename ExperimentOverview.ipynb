# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

vgg_only_validation_acc = [ 0.9870, 0.9906, 0.9880, 0.9912, 0.9874, 0.9916 ]
vgg_only_mnistc_acc = [ 0.8729, 0.8926, 0.8063, 0.8531, 0.8595, 0.8552 ]

print('VGG only')

print(f"Validation Accuracy:\tMean: {round(np.mean(vgg_only_validation_acc),4)}\tStd.: {round(np.std(vgg_only_validation_acc),4)}")
print(f"   MNIST-C Accuracy:\tMean: {round(np.mean(vgg_only_mnistc_acc),4)}\tStd.: {round(np.std(vgg_only_mnistc_acc),4)}")

print('---')
print('VGG+LCL')

vgg_lcl_validation_acc = [ 0.9882, 0.9917, 0.9899, 0.9903, 0.9881, 0.9911 ]
vgg_lcl_mnistc_acc = [ 0.8744, 0.86, 0.8453, 0.8754, 0.8997, 0.8844 ]
#vgg_lcl_validation_acc = [ 0.9882, 0.9853, 0.9899, 0.9903, 0.9881, 0.9911 ]
#vgg_lcl_mnistc_acc = [ 0.8744, 0.9103, 0.8453, 0.8754, 0.8997, 0.8844 ]

print(f"Validation Accuracy:\tMean: {round(np.mean(vgg_lcl_validation_acc),4)}\tStd.: {round(np.std(vgg_lcl_validation_acc),4)}")
print(f"   MNIST-C Accuracy:\tMean: {round(np.mean(vgg_lcl_mnistc_acc),4)}\tStd.: {round(np.std(vgg_lcl_mnistc_acc),4)}")
# Out:
# VGG only
# Validation Accuracy:	Mean: 0.9893	Std.: 0.0019
#    MNIST-C Accuracy:	Mean: 0.8566	Std.: 0.0262
# ---
# VGG+LCL
# Validation Accuracy:	Mean: 0.9899	Std.: 0.0014
#    MNIST-C Accuracy:	Mean: 0.8732	Std.: 0.0173

# %%
df_a = pd.read_csv('wandb_vggonly.csv')
df_b = pd.read_csv('wandb_vgglcl.csv')
df_c = pd.read_csv('wandb_vgg16lcl.csv')

df_c.head()
# Out:
#    iteration  VGG16_LCL_2022-04-07_112710 - _step  \
# 0       1250                                    5
# 1       2500                                   10
# 2       3750                                   15
# 3       5000                                   21
# 4       6250                                   26
#
#    VGG16_LCL_2022-04-07_112710 - _step__MIN  \
# 0                                         5
# 1                                        10
# 2                                        15
# 3                                        21
# 4                                        26
#
#    VGG16_LCL_2022-04-07_112710 - _step__MAX  \
# 0                                         5
# 1                                        10
# 2                                        15
# 3                                        21
# 4                                        26
#
#    VGG16_LCL_2022-04-07_112710 - test_acc  \
# 0                                  0.8568
# 1                                  0.8830
# 2                                  0.9031
# 3                                  0.9199
# 4                                  0.8753
#
#    VGG16_LCL_2022-04-07_112710 - test_acc__MIN  \
# 0                                       0.8568
# 1                                       0.8830
# 2                                       0.9031
# 3                                       0.9199
# 4                                       0.8753
#
#    VGG16_LCL_2022-04-07_112710 - test_acc__MAX  \
# 0                                       0.8568
# 1                                       0.8830
# 2                                       0.9031
# 3                                       0.9199
# 4                                       0.8753
#
#    VGG16_LCL_2022-04-07_112710 - test_loss  \
# 0                                 0.043743
# 1                                 0.038268
# 2                                 0.030542
# 3                                 0.025497
# 4                                 0.046535
#
#    VGG16_LCL_2022-04-07_112710 - test_loss__MIN  \
# 0                                      0.043743
# 1                                      0.038268
# 2                                      0.030542
# 3                                      0.025497
# 4                                      0.046535
#
#    VGG16_LCL_2022-04-07_112710 - test_loss__MAX  ...  \
# 0                                      0.043743  ...
# 1                                      0.038268  ...
# 2                                      0.030542  ...
# 3                                      0.025497  ...
# 4                                      0.046535  ...
#
#    VGG16_LCL_2022-04-07_112652 - test_acc__MAX  \
# 0                                       0.8377
# 1                                       0.8432
# 2                                       0.8076
# 3                                       0.8445
# 4                                       0.8422
#
#    VGG16_LCL_2022-04-07_112652 - test_loss  \
# 0                                 0.056917
# 1                                 0.048168
# 2                                 0.085618
# 3                                 0.057131
# 4                                 0.067315
#
#    VGG16_LCL_2022-04-07_112652 - test_loss__MIN  \
# 0                                      0.056917
# 1                                      0.048168
# 2                                      0.085618
# 3                                      0.057131
# 4                                      0.067315
#
#    VGG16_LCL_2022-04-07_112652 - test_loss__MAX  \
# 0                                      0.056917
# 1                                      0.048168
# 2                                      0.085618
# 3                                      0.057131
# 4                                      0.067315
#
#    VGG16_LCL_2022-04-07_112652 - val_acc  \
# 0                                 0.9597
# 1                                 0.9706
# 2                                 0.9740
# 3                                 0.9709
# 4                                 0.9825
#
#    VGG16_LCL_2022-04-07_112652 - val_acc__MIN  \
# 0                                      0.9597
# 1                                      0.9706
# 2                                      0.9740
# 3                                      0.9709
# 4                                      0.9825
#
#    VGG16_LCL_2022-04-07_112652 - val_acc__MAX  \
# 0                                      0.9597
# 1                                      0.9706
# 2                                      0.9740
# 3                                      0.9709
# 4                                      0.9825
#
#    VGG16_LCL_2022-04-07_112652 - val_loss  \
# 0                                0.013105
# 1                                0.009276
# 2                                0.009372
# 3                                0.009209
# 4                                0.005980
#
#    VGG16_LCL_2022-04-07_112652 - val_loss__MIN  \
# 0                                     0.013105
# 1                                     0.009276
# 2                                     0.009372
# 3                                     0.009209
# 4                                     0.005980
#
#    VGG16_LCL_2022-04-07_112652 - val_loss__MAX
# 0                                     0.013105
# 1                                     0.009276
# 2                                     0.009372
# 3                                     0.009209
# 4                                     0.005980
#
# [5 rows x 91 columns]

# %%
df_both = pd.merge(pd.merge(df_a, df_b), df_c)
model_names = sorted(list(set([x.split(' - ')[0] for x in df_both.columns])))[:-1]
model_names
# Out:
# ['VGG16_LCL_2022-04-07_112652',
#  'VGG16_LCL_2022-04-07_112710',
#  'VGG16_LCL_2022-04-07_202405',
#  'VGG16_LCL_2022-04-07_202410',
#  'VGG16_LCL_2022-04-08_013150',
#  'VGG16_LCL_2022-04-08_020051',
#  'VGG19_2022-04-04_160910',
#  'VGG19_2022-04-04_164603',
#  'VGG19_2022-04-04_172253',
#  'VGG19_2022-04-04_175945',
#  'VGG19_2022-04-04_183636',
#  'VGG19_2022-04-04_191333',
#  'VGG19_LCL_2022-04-05_124057',
#  'VGG19_LCL_2022-04-05_124104',
#  'VGG19_LCL_2022-04-05_155542',
#  'VGG19_LCL_2022-04-05_155601',
#  'VGG19_LCL_2022-04-05_171610',
#  'VGG19_LCL_2022-04-05_182033',
#  'VGG19_LCL_2022-04-05_205611',
#  'VGG19_LCL_2022-04-05_212941',
#  'VGG19_LCL_2022-04-05_214333',
#  'VGG19_LCL_2022-04-06_001414',
#  'VGG19_LCL_2022-04-06_015226',
#  'VGG19_LCL_2022-04-06_023811']

# %%
data = dict()
for m in model_names:
    tmp = {
        'iteration': np.array(df_both['iteration']),
        'val_acc': np.array(df_both[m + ' - val_acc']),
        'val_loss': np.array(df_both[m + ' - val_loss']),
        'test_acc': np.array(df_both[m + ' - test_acc']),
        'test_loss': np.array(df_both[m + ' - test_loss'])
    }
    data[m] = tmp
    
df = pd.DataFrame(data).transpose()
df['LCL'] = ['LCL' in x for x in df.index]

vgg_experiment = [ 'VGG19_2022-04-04_160910', 'VGG19_2022-04-04_164603', 'VGG19_2022-04-04_172253', 'VGG19_2022-04-04_175945', 'VGG19_2022-04-04_183636', 'VGG19_2022-04-04_191333' ]
iota_experiment = [ 'VGG19_LCL_2022-04-05_124057', 'VGG19_LCL_2022-04-05_124104', 'VGG19_LCL_2022-04-05_171610', 'VGG19_LCL_2022-04-05_182033', 'VGG19_LCL_2022-04-05_212941', 'VGG19_LCL_2022-04-06_001414']
eta_experiment = [ 'VGG19_LCL_2022-04-05_155542', 'VGG19_LCL_2022-04-05_155601', 'VGG19_LCL_2022-04-05_205611', 'VGG19_LCL_2022-04-05_214333', 'VGG19_LCL_2022-04-06_015226', 'VGG19_LCL_2022-04-06_023811' ]
experiment = []
for ix in df.index:
    if ix in iota_experiment:
        experiment.append('iota')
    elif ix in eta_experiment:
        experiment.append('eta')
    elif ix in vgg_experiment:
        experiment.append('vgg_only')
    else:
        experiment.append('vgg16_lcl')
df['experiment'] = experiment
df
# Out:
#                                                                      iteration  \
# VGG16_LCL_2022-04-07_112652  [1250, 2500, 3750, 5000, 6250, 7500, 8750, 100...
# VGG16_LCL_2022-04-07_112710  [1250, 2500, 3750, 5000, 6250, 7500, 8750, 100...
# VGG16_LCL_2022-04-07_202405  [1250, 2500, 3750, 5000, 6250, 7500, 8750, 100...
# VGG16_LCL_2022-04-07_202410  [1250, 2500, 3750, 5000, 6250, 7500, 8750, 100...
# VGG16_LCL_2022-04-08_013150  [1250, 2500, 3750, 5000, 6250, 7500, 8750, 100...
# VGG16_LCL_2022-04-08_020051  [1250, 2500, 3750, 5000, 6250, 7500, 8750, 100...
# VGG19_2022-04-04_160910      [1250, 2500, 3750, 5000, 6250, 7500, 8750, 100...
# VGG19_2022-04-04_164603      [1250, 2500, 3750, 5000, 6250, 7500, 8750, 100...
# VGG19_2022-04-04_172253      [1250, 2500, 3750, 5000, 6250, 7500, 8750, 100...
# VGG19_2022-04-04_175945      [1250, 2500, 3750, 5000, 6250, 7500, 8750, 100...
# VGG19_2022-04-04_183636      [1250, 2500, 3750, 5000, 6250, 7500, 8750, 100...
# VGG19_2022-04-04_191333      [1250, 2500, 3750, 5000, 6250, 7500, 8750, 100...
# VGG19_LCL_2022-04-05_124057  [1250, 2500, 3750, 5000, 6250, 7500, 8750, 100...
# VGG19_LCL_2022-04-05_124104  [1250, 2500, 3750, 5000, 6250, 7500, 8750, 100...
# VGG19_LCL_2022-04-05_155542  [1250, 2500, 3750, 5000, 6250, 7500, 8750, 100...
# VGG19_LCL_2022-04-05_155601  [1250, 2500, 3750, 5000, 6250, 7500, 8750, 100...
# VGG19_LCL_2022-04-05_171610  [1250, 2500, 3750, 5000, 6250, 7500, 8750, 100...
# VGG19_LCL_2022-04-05_182033  [1250, 2500, 3750, 5000, 6250, 7500, 8750, 100...
# VGG19_LCL_2022-04-05_205611  [1250, 2500, 3750, 5000, 6250, 7500, 8750, 100...
# VGG19_LCL_2022-04-05_212941  [1250, 2500, 3750, 5000, 6250, 7500, 8750, 100...
# VGG19_LCL_2022-04-05_214333  [1250, 2500, 3750, 5000, 6250, 7500, 8750, 100...
# VGG19_LCL_2022-04-06_001414  [1250, 2500, 3750, 5000, 6250, 7500, 8750, 100...
# VGG19_LCL_2022-04-06_015226  [1250, 2500, 3750, 5000, 6250, 7500, 8750, 100...
# VGG19_LCL_2022-04-06_023811  [1250, 2500, 3750, 5000, 6250, 7500, 8750, 100...
#
#                                                                        val_acc  \
# VGG16_LCL_2022-04-07_112652  [0.9597, 0.9706, 0.974, 0.9709, 0.9825, 0.9884...
# VGG16_LCL_2022-04-07_112710  [0.9575, 0.9753, 0.9807, 0.9847, 0.9812, 0.981...
# VGG16_LCL_2022-04-07_202405  [0.9541, 0.9743, 0.9794, 0.9826, 0.9772, 0.984...
# VGG16_LCL_2022-04-07_202410  [0.9583, 0.9726, 0.9774, 0.9844, 0.9872, 0.984...
# VGG16_LCL_2022-04-08_013150  [0.9495, 0.9661, 0.9805, 0.9796, 0.9788, 0.983...
# VGG16_LCL_2022-04-08_020051  [0.9507, 0.9737, 0.98, 0.9818, 0.9806, 0.982, ...
# VGG19_2022-04-04_160910      [0.9544, 0.9752, 0.9788, 0.9818, 0.988, 0.9842...
# VGG19_2022-04-04_164603      [0.9525, 0.9757, 0.9822, 0.9839, 0.9853, 0.986...
# VGG19_2022-04-04_172253      [0.9555, 0.9762, 0.9767, 0.9837, 0.9854, 0.979...
# VGG19_2022-04-04_175945      [0.9541, 0.9769, 0.9804, 0.9838, 0.9851, 0.988...
# VGG19_2022-04-04_183636      [0.9679, 0.9801, 0.9801, 0.9858, 0.9867, 0.986...
# VGG19_2022-04-04_191333      [0.9561, 0.9789, 0.9823, 0.9808, 0.9865, 0.988...
# VGG19_LCL_2022-04-05_124057  [0.9592, 0.9719, 0.9754, 0.9843, 0.9777, 0.982...
# VGG19_LCL_2022-04-05_124104  [0.9407, 0.9677, 0.9832, 0.9823, 0.9809, 0.983...
# VGG19_LCL_2022-04-05_155542  [0.9457, 0.9619, 0.9746, 0.98, 0.9848, 0.9793,...
# VGG19_LCL_2022-04-05_155601  [0.9648, 0.9628, 0.9795, 0.9776, 0.9853, 0.983...
# VGG19_LCL_2022-04-05_171610  [0.9666, 0.9716, 0.9789, 0.9845, 0.984, 0.9883...
# VGG19_LCL_2022-04-05_182033  [0.9096, 0.9698, 0.9762, 0.9826, 0.9876, 0.979...
# VGG19_LCL_2022-04-05_205611  [0.9593, 0.9802, 0.9792, 0.9814, 0.9847, 0.982...
# VGG19_LCL_2022-04-05_212941  [0.953, 0.9671, 0.978, 0.9792, 0.9804, 0.9857,...
# VGG19_LCL_2022-04-05_214333  [0.9467, 0.9733, 0.9542, 0.9835, 0.9842, 0.987...
# VGG19_LCL_2022-04-06_001414  [0.9557, 0.9757, 0.9818, 0.9827, 0.9787, 0.985...
# VGG19_LCL_2022-04-06_015226  [0.9553, 0.9765, 0.9804, 0.9801, 0.9847, 0.979...
# VGG19_LCL_2022-04-06_023811  [0.9496, 0.973, 0.9809, 0.9843, 0.9853, 0.9813...
#
#                                                                       val_loss  \
# VGG16_LCL_2022-04-07_112652  [0.0131054477828635, 0.0092764388716197, 0.009...
# VGG16_LCL_2022-04-07_112710  [0.0139069977276987, 0.0083167670360322, 0.006...
# VGG16_LCL_2022-04-07_202405  [0.015099963982866, 0.0091427274656016, 0.0066...
# VGG16_LCL_2022-04-07_202410  [0.0152219696494001, 0.0086542879049316, 0.007...
# VGG16_LCL_2022-04-08_013150  [0.0172693785491188, 0.0105434967866698, 0.006...
# VGG16_LCL_2022-04-08_020051  [0.0165872142625638, 0.0088576517282938, 0.006...
# VGG19_2022-04-04_160910      [0.0147651907822088, 0.0075237460005562, 0.007...
# VGG19_2022-04-04_164603      [0.0148849378283426, 0.007870561006134, 0.0062...
# VGG19_2022-04-04_172253      [0.0154697413544312, 0.0079382348750718, 0.007...
# VGG19_2022-04-04_175945      [0.0163810380998475, 0.0075473478723506, 0.006...
# VGG19_2022-04-04_183636      [0.0114716378124927, 0.0065999525326486, 0.006...
# VGG19_2022-04-04_191333      [0.0145032383279198, 0.0070667536373839, 0.006...
# VGG19_LCL_2022-04-05_124057  [0.0136803770799848, 0.0102002276436973, 0.007...
# VGG19_LCL_2022-04-05_124104  [0.0188577510904113, 0.0113217829054013, 0.006...
# VGG19_LCL_2022-04-05_155542  [0.016747953460551, 0.0132450157237298, 0.0086...
# VGG19_LCL_2022-04-05_214333  [0.771, 0.8198, 0.7864, 0.865, 0.8374, 0.8207,...
# VGG19_LCL_2022-04-06_001414  [0.8028, 0.8277, 0.8151, 0.8645, 0.7637, 0.833...
# VGG19_LCL_2022-04-06_015226  [0.8936, 0.8672, 0.874, 0.896, 0.875, 0.8456, ...
# VGG19_LCL_2022-04-06_023811  [0.8239, 0.7955, 0.8566, 0.8792, 0.8472, 0.806...
#
#                                                                      test_loss  \
# VGG16_LCL_2022-04-07_112652  [0.0569173373225378, 0.0481676572372904, 0.085...
# VGG16_LCL_2022-04-07_112710  [0.0437431449285068, 0.0382683835604431, 0.030...
# VGG16_LCL_2022-04-07_202405  [0.0376121961514505, 0.0448242178495507, 0.033...
# VGG16_LCL_2022-04-07_202410  [0.0747832117405749, 0.0341092174342193, 0.047...
# VGG16_LCL_2022-04-08_013150  [0.039591721514397, 0.0537966788519116, 0.0263...
# VGG16_LCL_2022-04-08_020051  [0.0506060833052906, 0.0484299033248884, 0.051...
# VGG19_2022-04-04_160910      [0.0371317461253376, 0.0535911920759826, 0.033...
# VGG19_2022-04-04_164603      [0.0752191783997462, 0.0393810492069926, 0.045...
# VGG19_2022-04-04_172253      [0.0537118549687555, 0.0662278074805508, 0.093...
# VGG19_2022-04-04_175945      [0.0632830979631398, 0.0466059953040211, 0.040...
# VGG19_2022-04-04_183636      [0.0548290259731192, 0.0405548672217526, 0.030...
# VGG19_2022-04-04_191333      [0.0626079597567906, 0.0554036206441524, 0.074...
# VGG19_LCL_2022-04-05_124057  [0.0439875084417087, 0.0593607313275096, 0.037...
# VGG19_LCL_2022-04-05_124104  [0.0878839029761263, 0.0705222711909795, 0.058...
# VGG19_LCL_2022-04-05_155542  [0.0488990880347671, 0.031703158939541, 0.0511...
# VGG19_LCL_2022-04-05_155601  [0.0412082484708168, 0.0304136333446949, 0.054...
# VGG19_LCL_2022-04-05_171610  [0.0457843051484786, 0.0608719751260243, 0.034...
# VGG19_LCL_2022-04-05_182033  [0.0848292805057251, 0.0524750863187014, 0.069...
# VGG19_LCL_2022-04-05_205611  [0.0639927712330594, 0.0497861502294079, 0.042...
# VGG19_LCL_2022-04-05_212941  [0.0843380679862574, 0.0817475972372806, 0.063...
# VGG19_LCL_2022-04-05_214333  [0.0775862583078444, 0.0524582908218959, 0.068...
# VGG19_LCL_2022-04-06_001414  [0.069237254285987, 0.0536708881800995, 0.0781...
# VGG19_LCL_2022-04-06_015226  [0.0343452642303396, 0.0405786530719138, 0.046...
# VGG19_LCL_2022-04-06_023811  [0.0547743447130546, 0.0646861444908194, 0.043...
#
#                                LCL experiment
# VGG16_LCL_2022-04-07_112652   True  vgg16_lcl
# VGG16_LCL_2022-04-07_112710   True  vgg16_lcl
# VGG16_LCL_2022-04-07_202405   True  vgg16_lcl
# VGG16_LCL_2022-04-07_202410   True  vgg16_lcl
# VGG16_LCL_2022-04-08_013150   True  vgg16_lcl
# VGG16_LCL_2022-04-08_020051   True  vgg16_lcl
# VGG19_2022-04-04_160910      False   vgg_only
# VGG19_2022-04-04_164603      False   vgg_only
# VGG19_2022-04-04_172253      False   vgg_only
# VGG19_2022-04-04_175945      False   vgg_only
# VGG19_2022-04-04_183636      False   vgg_only
# VGG19_2022-04-04_191333      False   vgg_only
# VGG19_LCL_2022-04-05_124057   True       iota
# VGG19_LCL_2022-04-05_124104   True       iota
# VGG19_LCL_2022-04-05_155542   True        eta
# VGG19_LCL_2022-04-05_155601   True        eta
# VGG19_LCL_2022-04-05_171610   True       iota
# VGG19_LCL_2022-04-05_182033   True       iota
# VGG19_LCL_2022-04-05_205611   True        eta
# VGG19_LCL_2022-04-05_212941   True       iota
# VGG19_LCL_2022-04-05_214333   True        eta
# VGG19_LCL_2022-04-06_001414   True       iota
# VGG19_LCL_2022-04-06_015226   True        eta
# VGG19_LCL_2022-04-06_023811   True        eta

# %%
for index, row in df.iterrows():
    best = 1000
    counter = 0
    best_index = [-1, -1, -1, -1]
    
    for i, val_loss in enumerate(row['val_loss']):
        
        if val_loss < best:
            best = val_loss
            counter = 0
        else:
            counter += 1

            if counter == 1:
                if best_index[0] < 0:
                    best_index[0] = i-1
                
            if counter == 2:
                if best_index[1] < 0:
                    best_index[1] = i-1
            
            if counter == 3:
                if best_index[2] < 0:
                    best_index[2] = i-1
                    
    for k, ix in enumerate(best_index):
        if ix == -1:
            best_index[k] = i
            
    df.loc[index, 'early_stop_1'] = best_index[0]
    df.loc[index, 'early_stop_2'] = best_index[1]
    df.loc[index, 'early_stop_3'] = best_index[2]
    df.loc[index, 'early_stop_4'] = best_index[2]
    
    best = 0
    counter = 0
    best_index = [-1, -1, -1, -1]
    
    for i, val_acc in enumerate(row['val_acc']):
        
        if val_acc > best:
            best = val_acc
            counter = 0
        else:
            counter += 1

            if counter == 1:
                if best_index[0] < 0:
                    best_index[0] = i-1
                
            if counter == 2:
                if best_index[1] < 0:
                    best_index[1] = i-1
            
            if counter == 3:
                if best_index[2] < 0:
                    best_index[2] = i-1
                    
    for k, ix in enumerate(best_index):
        if ix == -1:
            best_index[k] = i
            
    df.loc[index, 'early_stop_1__acc'] = best_index[0]
    df.loc[index, 'early_stop_2__acc'] = best_index[1]
    df.loc[index, 'early_stop_3__acc'] = best_index[2]
    df.loc[index, 'early_stop_4__acc'] = best_index[2]

# %%
df
# Out:
#                                                                      iteration  \
# VGG16_LCL_2022-04-07_112652  [1250, 2500, 3750, 5000, 6250, 7500, 8750, 100...
# VGG16_LCL_2022-04-07_112710  [1250, 2500, 3750, 5000, 6250, 7500, 8750, 100...
# VGG16_LCL_2022-04-07_202405  [1250, 2500, 3750, 5000, 6250, 7500, 8750, 100...
# VGG16_LCL_2022-04-07_202410  [1250, 2500, 3750, 5000, 6250, 7500, 8750, 100...
# VGG16_LCL_2022-04-08_013150  [1250, 2500, 3750, 5000, 6250, 7500, 8750, 100...
# VGG16_LCL_2022-04-08_020051  [1250, 2500, 3750, 5000, 6250, 7500, 8750, 100...
# VGG19_2022-04-04_160910      [1250, 2500, 3750, 5000, 6250, 7500, 8750, 100...
# VGG19_2022-04-04_164603      [1250, 2500, 3750, 5000, 6250, 7500, 8750, 100...
# VGG19_2022-04-04_172253      [1250, 2500, 3750, 5000, 6250, 7500, 8750, 100...
# VGG19_2022-04-04_175945      [1250, 2500, 3750, 5000, 6250, 7500, 8750, 100...
# VGG19_2022-04-04_183636      [1250, 2500, 3750, 5000, 6250, 7500, 8750, 100...
# VGG19_2022-04-04_191333      [1250, 2500, 3750, 5000, 6250, 7500, 8750, 100...
# VGG19_LCL_2022-04-05_124057  [1250, 2500, 3750, 5000, 6250, 7500, 8750, 100...
# VGG19_LCL_2022-04-05_124104  [1250, 2500, 3750, 5000, 6250, 7500, 8750, 100...
# VGG19_LCL_2022-04-05_155542  [1250, 2500, 3750, 5000, 6250, 7500, 8750, 100...
# VGG19_LCL_2022-04-05_155601  [1250, 2500, 3750, 5000, 6250, 7500, 8750, 100...
# VGG19_LCL_2022-04-05_171610  [1250, 2500, 3750, 5000, 6250, 7500, 8750, 100...
# VGG19_LCL_2022-04-05_182033  [1250, 2500, 3750, 5000, 6250, 7500, 8750, 100...
# VGG19_LCL_2022-04-05_205611  [1250, 2500, 3750, 5000, 6250, 7500, 8750, 100...
# VGG19_LCL_2022-04-05_212941  [1250, 2500, 3750, 5000, 6250, 7500, 8750, 100...
# VGG19_LCL_2022-04-05_214333  [1250, 2500, 3750, 5000, 6250, 7500, 8750, 100...
# VGG19_LCL_2022-04-06_001414  [1250, 2500, 3750, 5000, 6250, 7500, 8750, 100...
# VGG19_LCL_2022-04-06_015226  [1250, 2500, 3750, 5000, 6250, 7500, 8750, 100...
# VGG19_LCL_2022-04-06_023811  [1250, 2500, 3750, 5000, 6250, 7500, 8750, 100...
#
#                                                                        val_acc  \
# VGG16_LCL_2022-04-07_112652  [0.9597, 0.9706, 0.974, 0.9709, 0.9825, 0.9884...
# VGG16_LCL_2022-04-07_112710  [0.9575, 0.9753, 0.9807, 0.9847, 0.9812, 0.981...
# VGG16_LCL_2022-04-07_202405  [0.9541, 0.9743, 0.9794, 0.9826, 0.9772, 0.984...
# VGG16_LCL_2022-04-07_202410  [0.9583, 0.9726, 0.9774, 0.9844, 0.9872, 0.984...
# VGG16_LCL_2022-04-08_013150  [0.9495, 0.9661, 0.9805, 0.9796, 0.9788, 0.983...
# VGG16_LCL_2022-04-08_020051  [0.9507, 0.9737, 0.98, 0.9818, 0.9806, 0.982, ...
# VGG19_2022-04-04_160910      [0.9544, 0.9752, 0.9788, 0.9818, 0.988, 0.9842...
# VGG19_2022-04-04_164603      [0.9525, 0.9757, 0.9822, 0.9839, 0.9853, 0.986...
# VGG19_2022-04-04_172253      [0.9555, 0.9762, 0.9767, 0.9837, 0.9854, 0.979...
# VGG19_2022-04-04_175945      [0.9541, 0.9769, 0.9804, 0.9838, 0.9851, 0.988...
# VGG19_2022-04-04_183636      [0.9679, 0.9801, 0.9801, 0.9858, 0.9867, 0.986...
# VGG19_2022-04-04_191333      [0.9561, 0.9789, 0.9823, 0.9808, 0.9865, 0.988...
# VGG19_LCL_2022-04-05_124057  [0.9592, 0.9719, 0.9754, 0.9843, 0.9777, 0.982...
# VGG19_LCL_2022-04-05_124104  [0.9407, 0.9677, 0.9832, 0.9823, 0.9809, 0.983...
# VGG19_LCL_2022-04-05_155542  [0.9457, 0.9619, 0.9746, 0.98, 0.9848, 0.9793,...
# VGG19_LCL_2022-04-05_155601  [0.9648, 0.9628, 0.9795, 0.9776, 0.9853, 0.983...
# VGG19_LCL_2022-04-05_171610  [0.9666, 0.9716, 0.9789, 0.9845, 0.984, 0.9883...
# VGG19_LCL_2022-04-05_182033  [0.9096, 0.9698, 0.9762, 0.9826, 0.9876, 0.979...
# VGG19_LCL_2022-04-05_205611  [0.9593, 0.9802, 0.9792, 0.9814, 0.9847, 0.982...
# VGG19_LCL_2022-04-05_212941  [0.953, 0.9671, 0.978, 0.9792, 0.9804, 0.9857,...
# VGG19_LCL_2022-04-05_214333  [0.9467, 0.9733, 0.9542, 0.9835, 0.9842, 0.987...
# VGG19_LCL_2022-04-06_001414  [0.9557, 0.9757, 0.9818, 0.9827, 0.9787, 0.985...
# VGG19_LCL_2022-04-06_015226  [0.9553, 0.9765, 0.9804, 0.9801, 0.9847, 0.979...
# VGG19_LCL_2022-04-06_023811  [0.9496, 0.973, 0.9809, 0.9843, 0.9853, 0.9813...
#
#                                                                       val_loss  \
# VGG16_LCL_2022-04-07_112652  [0.0131054477828635, 0.0092764388716197, 0.009...
# VGG16_LCL_2022-04-07_112710  [0.0139069977276987, 0.0083167670360322, 0.006...
# VGG16_LCL_2022-04-07_202405  [0.015099963982866, 0.0091427274656016, 0.0066...
# VGG16_LCL_2022-04-07_202410  [0.0152219696494001, 0.0086542879049316, 0.007...
# VGG16_LCL_2022-04-08_013150  [0.0172693785491188, 0.0105434967866698, 0.006...
# VGG16_LCL_2022-04-08_020051  [0.0165872142625638, 0.0088576517282938, 0.006...
# VGG19_2022-04-04_160910      [0.0147651907822088, 0.0075237460005562, 0.007...
# VGG19_2022-04-04_164603      [0.0148849378283426, 0.007870561006134, 0.0062...
# VGG19_LCL_2022-04-05_182033          14.0          14.0                4.0
# VGG19_LCL_2022-04-05_205611          14.0          14.0                1.0
# VGG19_LCL_2022-04-05_212941           9.0           9.0                7.0
# VGG19_LCL_2022-04-05_214333          14.0          14.0                1.0
# VGG19_LCL_2022-04-06_001414          11.0          11.0                3.0
# VGG19_LCL_2022-04-06_015226          10.0          10.0                2.0
# VGG19_LCL_2022-04-06_023811          12.0          12.0                4.0
#
#                              early_stop_2__acc  early_stop_3__acc  \
# VGG16_LCL_2022-04-07_112652                6.0                7.0
# VGG16_LCL_2022-04-07_112710                4.0               11.0
# VGG16_LCL_2022-04-07_202405               11.0               12.0
# VGG16_LCL_2022-04-07_202410                7.0                8.0
# VGG16_LCL_2022-04-08_013150                3.0               14.0
# VGG16_LCL_2022-04-08_020051                7.0               14.0
# VGG19_2022-04-04_160910                    5.0                6.0
# VGG19_2022-04-04_164603                    6.0               14.0
# VGG19_2022-04-04_172253                   13.0               14.0
# VGG19_2022-04-04_175945                    6.0                7.0
# VGG19_2022-04-04_183636                    7.0                8.0
# VGG19_2022-04-04_191333                    6.0               14.0
# VGG19_LCL_2022-04-05_124057                4.0               14.0
# VGG19_LCL_2022-04-05_124104                3.0                4.0
# VGG19_LCL_2022-04-05_155542                8.0                9.0
# VGG19_LCL_2022-04-05_155601                7.0                8.0
# VGG19_LCL_2022-04-05_171610                8.0                9.0
# VGG19_LCL_2022-04-05_182033                5.0               14.0
# VGG19_LCL_2022-04-05_205611               10.0               11.0
# VGG19_LCL_2022-04-05_212941                8.0                9.0
# VGG19_LCL_2022-04-05_214333               14.0               14.0
# VGG19_LCL_2022-04-06_001414                7.0               11.0
# VGG19_LCL_2022-04-06_015226               14.0               14.0
# VGG19_LCL_2022-04-06_023811                7.0                8.0
#
#                              early_stop_4__acc
# VGG16_LCL_2022-04-07_112652                7.0
# VGG16_LCL_2022-04-07_112710               11.0
# VGG16_LCL_2022-04-07_202405               12.0
# VGG16_LCL_2022-04-07_202410                8.0
# VGG16_LCL_2022-04-08_013150               14.0
# VGG16_LCL_2022-04-08_020051               14.0
# VGG19_2022-04-04_160910                    6.0
# VGG19_2022-04-04_164603                   14.0
# VGG19_2022-04-04_172253                   14.0
# VGG19_2022-04-04_175945                    7.0
# VGG19_2022-04-04_183636                    8.0
# VGG19_2022-04-04_191333                   14.0
# VGG19_LCL_2022-04-05_124057               14.0
# VGG19_LCL_2022-04-05_124104                4.0
# VGG19_LCL_2022-04-05_155542                9.0
# VGG19_LCL_2022-04-05_155601                8.0
# VGG19_LCL_2022-04-05_171610                9.0
# VGG19_LCL_2022-04-05_182033               14.0
# VGG19_LCL_2022-04-05_205611               11.0
# VGG19_LCL_2022-04-05_212941                9.0
# VGG19_LCL_2022-04-05_214333               14.0
# VGG19_LCL_2022-04-06_001414               11.0
# VGG19_LCL_2022-04-06_015226               14.0
# VGG19_LCL_2022-04-06_023811                8.0

# %%
for early_stop in [1,2,3,4]:
    early_stop_idx = 'early_stop_' + str(early_stop)
    for index, row in df.iterrows():
        
        for attr in ['val_acc', 'val_loss', 'test_acc', 'test_loss']:
            df.loc[index, 'es'+str(early_stop)+'_' + attr] = row[attr][int(row[early_stop_idx])]
            
for early_stop in [1,2,3,4]:
    early_stop_idx = 'early_stop_' + str(early_stop) 
    for index, row in df.iterrows():
        for attr in ['val_acc', 'val_loss', 'test_acc', 'test_loss']:
            df.loc[index, 'es'+str(early_stop)+'_' + attr + '__acc'] = row[attr][int(row[early_stop_idx])]
df
# Out:
#                                                                      iteration  \
# VGG16_LCL_2022-04-07_112652  [1250, 2500, 3750, 5000, 6250, 7500, 8750, 100...
# VGG16_LCL_2022-04-07_112710  [1250, 2500, 3750, 5000, 6250, 7500, 8750, 100...
# VGG16_LCL_2022-04-07_202405  [1250, 2500, 3750, 5000, 6250, 7500, 8750, 100...
# VGG16_LCL_2022-04-07_202410  [1250, 2500, 3750, 5000, 6250, 7500, 8750, 100...
# VGG16_LCL_2022-04-08_013150  [1250, 2500, 3750, 5000, 6250, 7500, 8750, 100...
# VGG16_LCL_2022-04-08_020051  [1250, 2500, 3750, 5000, 6250, 7500, 8750, 100...
# VGG19_2022-04-04_160910      [1250, 2500, 3750, 5000, 6250, 7500, 8750, 100...
# VGG19_2022-04-04_164603      [1250, 2500, 3750, 5000, 6250, 7500, 8750, 100...
# VGG19_2022-04-04_172253      [1250, 2500, 3750, 5000, 6250, 7500, 8750, 100...
# VGG19_2022-04-04_175945      [1250, 2500, 3750, 5000, 6250, 7500, 8750, 100...
# VGG19_2022-04-04_183636      [1250, 2500, 3750, 5000, 6250, 7500, 8750, 100...
# VGG19_2022-04-04_191333      [1250, 2500, 3750, 5000, 6250, 7500, 8750, 100...
# VGG19_LCL_2022-04-05_124057  [1250, 2500, 3750, 5000, 6250, 7500, 8750, 100...
# VGG19_LCL_2022-04-05_124104  [1250, 2500, 3750, 5000, 6250, 7500, 8750, 100...
# VGG19_LCL_2022-04-05_155542  [1250, 2500, 3750, 5000, 6250, 7500, 8750, 100...
# VGG19_LCL_2022-04-05_155601  [1250, 2500, 3750, 5000, 6250, 7500, 8750, 100...
# VGG19_LCL_2022-04-05_171610  [1250, 2500, 3750, 5000, 6250, 7500, 8750, 100...
# VGG19_LCL_2022-04-05_182033  [1250, 2500, 3750, 5000, 6250, 7500, 8750, 100...
# VGG19_LCL_2022-04-05_205611  [1250, 2500, 3750, 5000, 6250, 7500, 8750, 100...
# VGG19_LCL_2022-04-05_212941  [1250, 2500, 3750, 5000, 6250, 7500, 8750, 100...
# VGG19_LCL_2022-04-05_214333  [1250, 2500, 3750, 5000, 6250, 7500, 8750, 100...
# VGG19_LCL_2022-04-06_001414  [1250, 2500, 3750, 5000, 6250, 7500, 8750, 100...
# VGG19_LCL_2022-04-06_015226  [1250, 2500, 3750, 5000, 6250, 7500, 8750, 100...
# VGG19_LCL_2022-04-06_023811  [1250, 2500, 3750, 5000, 6250, 7500, 8750, 100...
#
#                                                                        val_acc  \
# VGG16_LCL_2022-04-07_112652  [0.9597, 0.9706, 0.974, 0.9709, 0.9825, 0.9884...
# VGG16_LCL_2022-04-07_112710  [0.9575, 0.9753, 0.9807, 0.9847, 0.9812, 0.981...
# VGG16_LCL_2022-04-07_202405  [0.9541, 0.9743, 0.9794, 0.9826, 0.9772, 0.984...
# VGG16_LCL_2022-04-07_202410  [0.9583, 0.9726, 0.9774, 0.9844, 0.9872, 0.984...
# VGG16_LCL_2022-04-08_013150  [0.9495, 0.9661, 0.9805, 0.9796, 0.9788, 0.983...
# VGG16_LCL_2022-04-08_020051  [0.9507, 0.9737, 0.98, 0.9818, 0.9806, 0.982, ...
# VGG19_2022-04-04_160910      [0.9544, 0.9752, 0.9788, 0.9818, 0.988, 0.9842...
# VGG19_2022-04-04_164603      [0.9525, 0.9757, 0.9822, 0.9839, 0.9853, 0.986...
# VGG19_2022-04-04_172253      [0.9555, 0.9762, 0.9767, 0.9837, 0.9854, 0.979...
# VGG19_2022-04-04_175945      [0.9541, 0.9769, 0.9804, 0.9838, 0.9851, 0.988...
# VGG19_2022-04-04_183636      [0.9679, 0.9801, 0.9801, 0.9858, 0.9867, 0.986...
# VGG19_2022-04-04_191333      [0.9561, 0.9789, 0.9823, 0.9808, 0.9865, 0.988...
# VGG19_LCL_2022-04-05_124057  [0.9592, 0.9719, 0.9754, 0.9843, 0.9777, 0.982...
# VGG19_LCL_2022-04-05_124104  [0.9407, 0.9677, 0.9832, 0.9823, 0.9809, 0.983...
# VGG19_LCL_2022-04-05_155542  [0.9457, 0.9619, 0.9746, 0.98, 0.9848, 0.9793,...
# VGG19_LCL_2022-04-05_155601  [0.9648, 0.9628, 0.9795, 0.9776, 0.9853, 0.983...
# VGG19_LCL_2022-04-05_171610  [0.9666, 0.9716, 0.9789, 0.9845, 0.984, 0.9883...
# VGG19_LCL_2022-04-05_182033  [0.9096, 0.9698, 0.9762, 0.9826, 0.9876, 0.979...
# VGG19_LCL_2022-04-05_205611  [0.9593, 0.9802, 0.9792, 0.9814, 0.9847, 0.982...
# VGG16_LCL_2022-04-07_202405  [0.8821, 0.8495, 0.8903, 0.8722, 0.874, 0.886,...
# VGG16_LCL_2022-04-07_202410  [0.8185, 0.8866, 0.8477, 0.8081, 0.8309, 0.843...
# VGG16_LCL_2022-04-08_013150  [0.8866, 0.8384, 0.9138, 0.879, 0.8829, 0.9019...
# VGG16_LCL_2022-04-08_020051  [0.8533, 0.8633, 0.8475, 0.9008, 0.8466, 0.912...
# VGG19_2022-04-04_160910      [0.8809, 0.8439, 0.8872, 0.8583, 0.878, 0.8191...
# VGG19_2022-04-04_164603      [0.7939, 0.8756, 0.8699, 0.8037, 0.8464, 0.868...
# VGG19_2022-04-04_172253      [0.8407, 0.8153, 0.7785, 0.8089, 0.8402, 0.841...
# VGG19_2022-04-04_175945      [0.8176, 0.8539, 0.8692, 0.8528, 0.8306, 0.873...
# VGG19_2022-04-04_183636      [0.8589, 0.875, 0.8976, 0.9172, 0.9, 0.8604, 0...
# VGG19_2022-04-04_191333      [0.8188, 0.8381, 0.8063, 0.8678, 0.875, 0.8063...
# VGG19_LCL_2022-04-05_124057  [0.8585, 0.8511, 0.886, 0.8624, 0.802, 0.7703,...
# VGG19_LCL_2022-04-05_124104  [0.7614, 0.8072, 0.8307, 0.7949, 0.8037, 0.871...
# VGG19_LCL_2022-04-05_155542  [0.8439, 0.8987, 0.827, 0.8286, 0.9282, 0.8175...
# VGG19_LCL_2022-04-05_155601  [0.8798, 0.8987, 0.8542, 0.8353, 0.9103, 0.898...
# VGG19_LCL_2022-04-05_171610  [0.8583, 0.7943, 0.8865, 0.8673, 0.9036, 0.867...
# VGG19_LCL_2022-04-05_182033  [0.768, 0.8318, 0.8194, 0.8785, 0.8717, 0.8372...
# VGG19_LCL_2022-04-05_205611  [0.7987, 0.8392, 0.8621, 0.9002, 0.8432, 0.852...
# VGG19_LCL_2022-04-05_212941  [0.7354, 0.7805, 0.7925, 0.8332, 0.8091, 0.814...
# VGG19_LCL_2022-04-05_214333  [0.771, 0.8198, 0.7864, 0.865, 0.8374, 0.8207,...
# VGG19_LCL_2022-04-06_001414  [0.8028, 0.8277, 0.8151, 0.8645, 0.7637, 0.833...
# VGG19_LCL_2022-04-06_015226  [0.8936, 0.8672, 0.874, 0.896, 0.875, 0.8456, ...
# VGG19_LCL_2022-04-06_023811  [0.8239, 0.7955, 0.8566, 0.8792, 0.8472, 0.806...
#
#                                                                      test_loss  \
# VGG16_LCL_2022-04-07_112652  [0.0569173373225378, 0.0481676572372904, 0.085...
# VGG16_LCL_2022-04-07_112710  [0.0437431449285068, 0.0382683835604431, 0.030...
# VGG16_LCL_2022-04-07_202405  [0.0376121961514505, 0.0448242178495507, 0.033...
# VGG16_LCL_2022-04-07_202410  [0.0747832117405749, 0.0341092174342193, 0.047...
# VGG16_LCL_2022-04-08_013150  [0.039591721514397, 0.0537966788519116, 0.0263...
# VGG16_LCL_2022-04-08_020051  [0.0506060833052906, 0.0484299033248884, 0.051...
# VGG19_2022-04-04_160910      [0.0371317461253376, 0.0535911920759826, 0.033...
# VGG19_2022-04-04_164603      [0.0752191783997462, 0.0393810492069926, 0.045...
# VGG19_2022-04-04_172253      [0.0537118549687555, 0.0662278074805508, 0.093...
# VGG19_2022-04-04_175945      [0.0632830979631398, 0.0466059953040211, 0.040...
# VGG19_2022-04-04_183636      [0.0548290259731192, 0.0405548672217526, 0.030...
# VGG19_2022-04-04_191333      [0.0626079597567906, 0.0554036206441524, 0.074...
# VGG19_LCL_2022-04-05_124057  [0.0439875084417087, 0.0593607313275096, 0.037...
# VGG19_LCL_2022-04-05_124104  [0.0878839029761263, 0.0705222711909795, 0.058...
# VGG19_LCL_2022-04-05_155542  [0.0488990880347671, 0.031703158939541, 0.0511...
# VGG19_LCL_2022-04-05_155601  [0.0412082484708168, 0.0304136333446949, 0.054...
# VGG19_LCL_2022-04-05_171610  [0.0457843051484786, 0.0608719751260243, 0.034...
# VGG19_LCL_2022-04-05_182033  [0.0848292805057251, 0.0524750863187014, 0.069...
# VGG19_LCL_2022-04-05_205611  [0.0639927712330594, 0.0497861502294079, 0.042...
# VGG19_LCL_2022-04-05_212941  [0.0843380679862574, 0.0817475972372806, 0.063...
# VGG19_LCL_2022-04-05_214333  [0.0775862583078444, 0.0524582908218959, 0.068...
# VGG19_LCL_2022-04-06_001414  [0.069237254285987, 0.0536708881800995, 0.0781...
# VGG19_LCL_2022-04-06_015226  [0.0343452642303396, 0.0405786530719138, 0.046...
# VGG19_LCL_2022-04-06_023811  [0.0547743447130546, 0.0646861444908194, 0.043...
#
#                                LCL experiment  early_stop_1  early_stop_2  \
# VGG16_LCL_2022-04-07_112652   True  vgg16_lcl           1.0           6.0
# VGG16_LCL_2022-04-07_112710   True  vgg16_lcl           3.0           4.0
# VGG16_LCL_2022-04-07_202405   True  vgg16_lcl           3.0          10.0
# VGG16_LCL_2022-04-07_202410   True  vgg16_lcl           4.0           7.0
# VGG16_LCL_2022-04-08_013150   True  vgg16_lcl           3.0          14.0
# VGG16_LCL_2022-04-08_020051   True  vgg16_lcl           3.0           4.0
# VGG19_2022-04-04_160910      False   vgg_only           4.0           5.0
# VGG19_2022-04-04_164603      False   vgg_only           5.0           6.0
# VGG19_2022-04-04_172253      False   vgg_only           4.0           7.0
# VGG19_2022-04-04_175945      False   vgg_only           5.0           8.0
# VGG19_2022-04-04_183636      False   vgg_only           3.0          11.0
# VGG19_2022-04-04_191333      False   vgg_only           2.0           6.0
# VGG19_LCL_2022-04-05_124057   True       iota           3.0           4.0
# VGG19_LCL_2022-04-05_124104   True       iota           2.0           3.0
# VGG19_LCL_2022-04-05_155542   True        eta           4.0           8.0
# VGG19_LCL_2022-04-05_155601   True        eta           0.0          12.0
# VGG19_LCL_2022-04-05_171610   True       iota           3.0           9.0
# VGG19_LCL_2022-04-05_182033   True       iota           4.0           5.0
# VGG19_LCL_2022-04-05_205611   True        eta           4.0          12.0
# VGG19_LCL_2022-04-05_212941   True       iota           7.0           8.0
# VGG19_LCL_2022-04-05_214333   True        eta           1.0          11.0
# VGG19_LCL_2022-04-06_001414   True       iota           3.0           7.0
# VGG19_LCL_2022-04-06_015226   True        eta           4.0           9.0
# VGG19_LCL_2022-04-06_023811   True        eta           3.0           4.0
#
#                              early_stop_3  ...  es2_test_acc__acc  \
# VGG16_LCL_2022-04-07_112652          14.0  ...             0.7696
# VGG16_LCL_2022-04-07_112710           9.0  ...             0.8753
# VGG16_LCL_2022-04-07_202405          11.0  ...             0.9024
# VGG16_LCL_2022-04-07_202410          13.0  ...             0.8636
# VGG16_LCL_2022-04-08_013150          14.0  ...             0.9026
# VGG16_LCL_2022-04-08_020051           8.0  ...             0.8466
# VGG19_2022-04-04_160910               6.0  ...             0.8191
# VGG19_2022-04-04_164603              14.0  ...             0.8696
# VGG19_2022-04-04_172253               8.0  ...             0.8297
# VGG19_2022-04-04_175945               9.0  ...             0.8619
# VGG19_2022-04-04_183636              12.0  ...             0.8455
# VGG19_2022-04-04_191333               7.0  ...             0.7872
# VGG19_LCL_2022-04-05_124057          10.0  ...             0.8020
# VGG19_LCL_2022-04-05_124104          14.0  ...             0.7949
# VGG19_LCL_2022-04-05_155542           9.0  ...             0.8116
# VGG19_LCL_2022-04-05_155601          13.0  ...             0.9243
# VGG19_LCL_2022-04-05_171610          10.0  ...             0.8729
# VGG19_LCL_2022-04-05_182033          14.0  ...             0.8372
# VGG19_LCL_2022-04-05_205611          14.0  ...             0.8617
# VGG19_LCL_2022-04-05_212941           9.0  ...             0.8198
# VGG19_LCL_2022-04-05_214333          14.0  ...             0.8950
# VGG19_LCL_2022-04-06_001414          11.0  ...             0.8399
# VGG19_LCL_2022-04-06_015226          10.0  ...             0.8981
# VGG19_LCL_2022-04-06_023811          12.0  ...             0.8472
#
#                              es2_test_loss__acc  es3_val_acc__acc  \
# VGG16_LCL_2022-04-07_112652            0.084216            0.9858
# VGG16_LCL_2022-04-07_112710            0.046535            0.9891
# VGG16_LCL_2022-04-07_202405            0.035221            0.9864
# VGG16_LCL_2022-04-07_202410            0.045741            0.9881
# VGG16_LCL_2022-04-08_013150            0.039874            0.9907
# VGG16_LCL_2022-04-08_020051            0.047657            0.9843
# VGG19_2022-04-04_160910                0.088876            0.9763
# VGG19_2022-04-04_164603                0.047412            0.9916
# VGG19_2022-04-04_172253                0.078165            0.9875
# VGG19_2022-04-04_175945                0.049676            0.9893
# VGG19_2022-04-04_183636                0.072540            0.9914
# VGG19_2022-04-04_191333                0.075548            0.9867
# VGG19_LCL_2022-04-05_124057            0.069971            0.9897
# VGG19_LCL_2022-04-05_124104            0.072518            0.9892
# VGG19_LCL_2022-04-05_155542            0.100514            0.9853
# VGG19_LCL_2022-04-05_155601            0.023584            0.9896
# VGG19_LCL_2022-04-05_171610            0.046859            0.9863
# VGG19_LCL_2022-04-05_182033            0.054907            0.9892
# VGG19_LCL_2022-04-05_205611            0.057513            0.9899
# VGG19_LCL_2022-04-05_212941            0.065381            0.9870
# VGG19_LCL_2022-04-05_214333            0.035764            0.9903
# VGG19_LCL_2022-04-06_001414            0.060205            0.9868
# VGG19_LCL_2022-04-06_015226            0.035451            0.9879
# VGG19_LCL_2022-04-06_023811            0.053891            0.9867
#
#                              es3_val_loss__acc  es3_test_acc__acc  \
# VGG16_LCL_2022-04-07_112652           0.005938             0.8015
# VGG16_LCL_2022-04-07_112710           0.004252             0.8974
# VGG16_LCL_2022-04-07_202405           0.004364             0.8717
# VGG16_LCL_2022-04-07_202410           0.004505             0.8434
# VGG16_LCL_2022-04-08_013150           0.002969             0.9026
# VGG16_LCL_2022-04-08_020051           0.005981             0.8828
# VGG19_2022-04-04_160910               0.007764             0.8333
# VGG19_2022-04-04_164603               0.002957             0.8552
# VGG19_2022-04-04_172253               0.004539             0.8599
# VGG19_2022-04-04_175945               0.003970             0.8567
# VGG19_2022-04-04_183636               0.003212             0.8683
# VGG19_2022-04-04_191333               0.004456             0.8044
# VGG19_LCL_2022-04-05_124057           0.003808             0.8821
# VGG19_LCL_2022-04-05_124104           0.003752             0.8382
# VGG19_LCL_2022-04-05_155542           0.005758             0.8511
# VGG19_LCL_2022-04-05_155601           0.003788             0.8727
# VGG19_LCL_2022-04-05_171610           0.005088             0.8102
# VGG19_LCL_2022-04-05_182033           0.003756             0.8670
# VGG19_LCL_2022-04-05_205611           0.003233             0.8453
# VGG19_LCL_2022-04-05_212941           0.004960             0.7833
# VGG19_LCL_2022-04-05_214333           0.003454             0.8754
# VGG19_LCL_2022-04-06_001414           0.004484             0.8483
# VGG19_LCL_2022-04-06_015226           0.003678             0.9281
# VGG19_LCL_2022-04-06_023811           0.005136             0.8643
#
#                              es3_test_loss__acc  es4_val_acc__acc  \
# VGG16_LCL_2022-04-07_112652            0.108386            0.9858
# VGG16_LCL_2022-04-07_112710            0.037718            0.9891
# VGG16_LCL_2022-04-07_202405            0.048513            0.9864
# VGG16_LCL_2022-04-07_202410            0.071255            0.9881
# VGG16_LCL_2022-04-08_013150            0.039874            0.9907
# VGG16_LCL_2022-04-08_020051            0.045307            0.9843
# VGG19_2022-04-04_160910                0.052053            0.9763
# VGG19_2022-04-04_164603                0.074634            0.9916
# VGG19_2022-04-04_172253                0.057130            0.9875
# VGG19_2022-04-04_175945                0.053302            0.9893
# VGG19_2022-04-04_183636                0.047288            0.9914
# VGG19_2022-04-04_191333                0.081459            0.9867
# VGG19_LCL_2022-04-05_124057            0.049270            0.9897
# VGG19_LCL_2022-04-05_124104            0.060457            0.9892
# VGG19_LCL_2022-04-05_155542            0.062635            0.9853
# VGG19_LCL_2022-04-05_155601            0.055922            0.9896
# VGG19_LCL_2022-04-05_171610            0.060553            0.9863
# VGG19_LCL_2022-04-05_182033            0.041741            0.9892
# VGG19_LCL_2022-04-05_205611            0.058481            0.9899
# VGG19_LCL_2022-04-05_212941            0.107482            0.9870
# VGG19_LCL_2022-04-05_214333            0.046262            0.9903
# VGG19_LCL_2022-04-06_001414            0.057882            0.9868
# VGG19_LCL_2022-04-06_015226            0.021956            0.9879
# VGG19_LCL_2022-04-06_023811            0.063504            0.9867
#
#                              es4_val_loss__acc  es4_test_acc__acc  \
# VGG16_LCL_2022-04-07_112652           0.005938             0.8015
# VGG16_LCL_2022-04-07_112710           0.004252             0.8974
# VGG16_LCL_2022-04-07_202405           0.004364             0.8717
# VGG16_LCL_2022-04-07_202410           0.004505             0.8434
# VGG16_LCL_2022-04-08_013150           0.002969             0.9026
# VGG16_LCL_2022-04-08_020051           0.005981             0.8828
# VGG19_2022-04-04_160910               0.007764             0.8333
# VGG19_2022-04-04_164603               0.002957             0.8552
# VGG19_2022-04-04_172253               0.004539             0.8599
# VGG19_2022-04-04_175945               0.003970             0.8567
# VGG19_2022-04-04_183636               0.003212             0.8683
# VGG19_2022-04-04_191333               0.004456             0.8044
# VGG19_LCL_2022-04-05_124057           0.003808             0.8821
# VGG19_LCL_2022-04-05_124104           0.003752             0.8382
# VGG19_LCL_2022-04-05_155542           0.005758             0.8511
# VGG19_LCL_2022-04-05_155601           0.003788             0.8727
# VGG19_LCL_2022-04-05_171610           0.005088             0.8102
# VGG19_LCL_2022-04-05_182033           0.003756             0.8670
# VGG19_LCL_2022-04-05_205611           0.003233             0.8453
# VGG19_LCL_2022-04-05_212941           0.004960             0.7833
# VGG19_LCL_2022-04-05_214333           0.003454             0.8754
# VGG19_LCL_2022-04-06_001414           0.004484             0.8483
# VGG19_LCL_2022-04-06_015226           0.003678             0.9281
# VGG19_LCL_2022-04-06_023811           0.005136             0.8643
#
#                              es4_test_loss__acc
# VGG16_LCL_2022-04-07_112652            0.108386
# VGG16_LCL_2022-04-07_112710            0.037718
# VGG16_LCL_2022-04-07_202405            0.048513
# VGG16_LCL_2022-04-07_202410            0.071255
# VGG16_LCL_2022-04-08_013150            0.039874
# VGG16_LCL_2022-04-08_020051            0.045307
# VGG19_2022-04-04_160910                0.052053
# VGG19_2022-04-04_164603                0.074634
# VGG19_2022-04-04_172253                0.057130
# VGG19_2022-04-04_175945                0.053302
# VGG19_2022-04-04_183636                0.047288
# VGG19_2022-04-04_191333                0.081459
# VGG19_LCL_2022-04-05_124057            0.049270
# VGG19_LCL_2022-04-05_124104            0.060457
# VGG19_LCL_2022-04-05_155542            0.062635
# VGG19_LCL_2022-04-05_155601            0.055922
# VGG19_LCL_2022-04-05_171610            0.060553
# VGG19_LCL_2022-04-05_182033            0.041741
# VGG19_LCL_2022-04-05_205611            0.058481
# VGG19_LCL_2022-04-05_212941            0.107482
# VGG19_LCL_2022-04-05_214333            0.046262
# VGG19_LCL_2022-04-06_001414            0.057882
# VGG19_LCL_2022-04-06_015226            0.021956
# VGG19_LCL_2022-04-06_023811            0.063504
#
# [24 rows x 47 columns]

# %% [markdown]
# ### Early Stopping using VAL_LOSS

# %%
for es in [1,2,3,4]:
    gb = df.groupby(['experiment'])

    val_acc = gb.mean()['es'+str(es)+'_val_acc']
    val_acc_std = gb.std()['es'+str(es)+'_val_acc']
    test_acc = gb.mean()['es'+str(es)+'_test_acc']
    test_acc_std = gb.std()['es'+str(es)+'_test_acc']
    
    print('')
    print('---')
    print(f"EARLY STOPPING {es}")
    for e in df['experiment'].unique():
        print(f"{e.ljust(10)}\tVal: {str(round(val_acc[e],4)).ljust(6)} (Std: {str(round(val_acc_std[e],4)).ljust(6)})\tVal: {str(round(test_acc[e],4)).ljust(6)} (Std: {str(round(test_acc_std[e],4)).ljust(6)})")
# Out:
# ---
# EARLY STOPPING 1
# vgg16_lcl 	Val: 0.9811 (Std: 0.0058)	Val: 0.8743 (Std: 0.0336)
# vgg_only  	Val: 0.986  (Std: 0.0021)	Val: 0.864  (Std: 0.0375)
# iota      	Val: 0.9851 (Std: 0.0024)	Val: 0.85   (Std: 0.0272)
# eta       	Val: 0.9794 (Std: 0.0085)	Val: 0.8709 (Std: 0.037 )
#
# ---
# EARLY STOPPING 2
# vgg16_lcl 	Val: 0.9849 (Std: 0.005 )	Val: 0.86   (Std: 0.0494)
# vgg_only  	Val: 0.9864 (Std: 0.0022)	Val: 0.8355 (Std: 0.0303)
# iota      	Val: 0.9832 (Std: 0.0041)	Val: 0.8278 (Std: 0.0286)
# eta       	Val: 0.9867 (Std: 0.0022)	Val: 0.873  (Std: 0.0408)
#
# ---
# EARLY STOPPING 3
# vgg16_lcl 	Val: 0.9874 (Std: 0.0023)	Val: 0.8666 (Std: 0.0382)
# vgg_only  	Val: 0.9871 (Std: 0.0057)	Val: 0.8463 (Std: 0.0236)
# iota      	Val: 0.988  (Std: 0.0015)	Val: 0.8382 (Std: 0.0365)
# eta       	Val: 0.9883 (Std: 0.002 )	Val: 0.8728 (Std: 0.0295)
#
# ---
# EARLY STOPPING 4
# vgg16_lcl 	Val: 0.9874 (Std: 0.0023)	Val: 0.8666 (Std: 0.0382)
# vgg_only  	Val: 0.9871 (Std: 0.0057)	Val: 0.8463 (Std: 0.0236)
# iota      	Val: 0.988  (Std: 0.0015)	Val: 0.8382 (Std: 0.0365)
# eta       	Val: 0.9883 (Std: 0.002 )	Val: 0.8728 (Std: 0.0295)

# %% [markdown]
# ### Early Stopping using VAL_ACC

# %%
for es in [1,2,3,4]:
    gb = df.groupby(['experiment'])

    val_acc = gb.mean()['es'+str(es)+'_val_acc__acc']
    val_acc_std = gb.std()['es'+str(es)+'_val_acc__acc']
    test_acc = gb.mean()['es'+str(es)+'_test_acc__acc']
    test_acc_std = gb.std()['es'+str(es)+'_test_acc__acc']
    
    print('')
    print('---')
    print(f"EARLY STOPPING {es}")
    for e in df['experiment'].unique():
        print(f"{e.ljust(10)}\tVal: {str(round(val_acc[e],4)).ljust(6)} (Std: {str(round(val_acc_std[e],4)).ljust(6)})\tVal: {str(round(test_acc[e],4)).ljust(6)} (Std: {str(round(test_acc_std[e],4)).ljust(6)})")
# Out:
# ---
# EARLY STOPPING 1
# vgg16_lcl 	Val: 0.9811 (Std: 0.0058)	Val: 0.8743 (Std: 0.0336)
# vgg_only  	Val: 0.986  (Std: 0.0021)	Val: 0.864  (Std: 0.0375)
# iota      	Val: 0.9851 (Std: 0.0024)	Val: 0.85   (Std: 0.0272)
# eta       	Val: 0.9794 (Std: 0.0085)	Val: 0.8709 (Std: 0.037 )
#
# ---
# EARLY STOPPING 2
# vgg16_lcl 	Val: 0.9849 (Std: 0.005 )	Val: 0.86   (Std: 0.0494)
# vgg_only  	Val: 0.9864 (Std: 0.0022)	Val: 0.8355 (Std: 0.0303)
# iota      	Val: 0.9832 (Std: 0.0041)	Val: 0.8278 (Std: 0.0286)
# eta       	Val: 0.9867 (Std: 0.0022)	Val: 0.873  (Std: 0.0408)
#
# ---
# EARLY STOPPING 3
# vgg16_lcl 	Val: 0.9874 (Std: 0.0023)	Val: 0.8666 (Std: 0.0382)
# vgg_only  	Val: 0.9871 (Std: 0.0057)	Val: 0.8463 (Std: 0.0236)
# iota      	Val: 0.988  (Std: 0.0015)	Val: 0.8382 (Std: 0.0365)
# eta       	Val: 0.9883 (Std: 0.002 )	Val: 0.8728 (Std: 0.0295)
#
# ---
# EARLY STOPPING 4
# vgg16_lcl 	Val: 0.9874 (Std: 0.0023)	Val: 0.8666 (Std: 0.0382)
# vgg_only  	Val: 0.9871 (Std: 0.0057)	Val: 0.8463 (Std: 0.0236)
# iota      	Val: 0.988  (Std: 0.0015)	Val: 0.8382 (Std: 0.0365)
# eta       	Val: 0.9883 (Std: 0.002 )	Val: 0.8728 (Std: 0.0295)

# %%
fig, axs = plt.subplots(1, 2, figsize=(9,4))

data0 = [ vgg_only_validation_acc, vgg_lcl_validation_acc ]
data1 = [ vgg_only_mnistc_acc, vgg_lcl_mnistc_acc ]

axs[0].boxplot(data0)
axs[0].set_xticklabels(['Vgg19', 'Vgg19+LCL'])
axs[0].set_ylim([0.98, 1])
axs[0].set_title('MNIST')
axs[0].set_ylabel('Accuracy')

axs[1].boxplot(data1)
axs[1].set_xticklabels(['Vgg19', 'Vgg19+LCL'])
axs[1].set_ylim(bottom=0.8)
axs[1].set_title('MNIST-C "Line"')
axs[1].set_ylabel('Accuracy')
plt.tight_layout()

# %%
fig, axs = plt.subplots(1,2)
axs[0].scatter([0 for i in range(6)], vgg_lcl_mnistc_acc)
axs[0].scatter([1 for i in range(6)], vgg_only_mnistc_acc)
axs[0].set_xlim([-0.5, 1.5])
axs[1].scatter([0 for i in range(6)], vgg_lcl_validation_acc)
axs[1].scatter([1 for i in range(6)], vgg_only_validation_acc)
axs[1].set_xlim([-0.5, 1.5])
# Out:
# (-0.5, 1.5)

# %%
for i, row in df.iterrows():
    if not row['experiment'] == 'iota':
        iteration = row['iteration'][int(row['early_stop_3'])]
        print(f"{i}__it{iteration}_e{iteration//5000}.pt")
# Out:
# VGG16_LCL_2022-04-07_112652__it18750_e3.pt
# VGG16_LCL_2022-04-07_112710__it12500_e2.pt
# VGG16_LCL_2022-04-07_202405__it15000_e3.pt
# VGG16_LCL_2022-04-07_202410__it17500_e3.pt
# VGG16_LCL_2022-04-08_013150__it18750_e3.pt
# VGG16_LCL_2022-04-08_020051__it11250_e2.pt
# VGG19_2022-04-04_160910__it8750_e1.pt
# VGG19_2022-04-04_164603__it18750_e3.pt
# VGG19_2022-04-04_172253__it11250_e2.pt
# VGG19_2022-04-04_175945__it12500_e2.pt
# VGG19_2022-04-04_183636__it16250_e3.pt
# VGG19_2022-04-04_191333__it10000_e2.pt
# VGG19_LCL_2022-04-05_155542__it12500_e2.pt
# VGG19_LCL_2022-04-05_155601__it17500_e3.pt
# VGG19_LCL_2022-04-05_205611__it18750_e3.pt
# VGG19_LCL_2022-04-05_214333__it18750_e3.pt
# VGG19_LCL_2022-04-06_015226__it13750_e2.pt
# VGG19_LCL_2022-04-06_023811__it16250_e3.pt

# %% [markdown]
# ### All MNIST-C Variants

# %%
import pandas as pd
df_lcl = pd.read_csv('mnist_c__lcl.csv')
df_lcl['experiment'] = 'VGG19+LCL'

df_vgg = pd.read_csv('mnist_c__vggonly.csv')
df_vgg['experiment'] = 'VGG19'

df_vgg16_1 = pd.read_csv('mnist_c__vgg16_lcl01.csv')
df_vgg16_1['experiment'] = 'VGG16+LCL'
df_vgg16_2 = pd.read_csv('mnist_c__vgg16_lcl23.csv')
df_vgg16_2['experiment'] = 'VGG16+LCL'
df_vgg16_3 = pd.read_csv('mnist_c__vgg16_lcl45.csv')
df_vgg16_3['experiment'] = 'VGG16+LCL'


df = df_lcl.append(df_vgg)
df = df.append(df_vgg16_1)
df = df.append(df_vgg16_2)
df = df.append(df_vgg16_3).reset_index()
df = df[['model','mnist_c_variant','accuracy','experiment']]
print(df.groupby(['experiment']).count())
df
# Out:
#             model  mnist_c_variant  accuracy
# experiment
# VGG16+LCL      90               90        90
# VGG19          90               90        90
# VGG19+LCL      90               90        90
#                                           model    mnist_c_variant  accuracy  \
# 0    VGG19_LCL_2022-04-05_155542__it12500_e2.pt               line    0.8511
# 1    VGG19_LCL_2022-04-05_155542__it12500_e2.pt  elastic_transform    0.8543
# 2    VGG19_LCL_2022-04-05_155542__it12500_e2.pt             zigzag    0.8723
# 3    VGG19_LCL_2022-04-05_155542__it12500_e2.pt        motion_blur    0.9133
# 4    VGG19_LCL_2022-04-05_155542__it12500_e2.pt      gaussian_blur    0.9078
# ..                                          ...                ...       ...
# 265  VGG16_LCL_2022-04-08_020051__it11250_e2.pt     gaussian_noise    0.9665
# 266  VGG16_LCL_2022-04-08_020051__it11250_e2.pt           pixelate    0.9424
# 267  VGG16_LCL_2022-04-08_020051__it11250_e2.pt          zoom_blur    0.9693
# 268  VGG16_LCL_2022-04-08_020051__it11250_e2.pt         shot_noise    0.9745
# 269  VGG16_LCL_2022-04-08_020051__it11250_e2.pt                fog    0.9747
#
#     experiment
# 0    VGG19+LCL
# 1    VGG19+LCL
# 2    VGG19+LCL
# 3    VGG19+LCL
# 4    VGG19+LCL
# ..         ...
# 265  VGG16+LCL
# 266  VGG16+LCL
# 267  VGG16+LCL
# 268  VGG16+LCL
# 269  VGG16+LCL
#
# [270 rows x 4 columns]

# %%
df_mean = df.groupby(['mnist_c_variant', 'experiment']).mean()['accuracy']
df_std = df.groupby(['mnist_c_variant', 'experiment']).std()['accuracy']

def filter_vgg_lcl(df, attr):
    df_x = df.reset_index()
    df_x = df_x[df_x['experiment'] == 'VGG19+LCL'][['mnist_c_variant','accuracy']]
    df_x.columns = ['mnist_c', attr+'_lcl']
    df_x

    df_y = df.reset_index()
    df_y = df_y[df_y['experiment'] == 'VGG19'][['mnist_c_variant','accuracy']]
    df_y.columns = ['mnist_c', attr+'_vgg']
    df_y

    df_z = df.reset_index()
    df_z = df_z[df_z['experiment'] == 'VGG16+LCL'][['mnist_c_variant','accuracy']]
    df_z.columns = ['mnist_c', attr+'_lcl16']
    df_z
    
    return df_x, df_y, df_z
    
a,b,c = filter_vgg_lcl(df_mean, 'accuracy')
d,e,f = filter_vgg_lcl(df_std, 'std')



dfx = pd.merge(pd.merge(pd.merge(a,b), pd.merge(c,d)),pd.merge(e,f))
dfx
# Out:
#               mnist_c  accuracy_lcl  accuracy_vgg  accuracy_lcl16   std_lcl  \
# 0        defocus_blur      0.946200      0.944917        0.930167  0.009149
# 1         dotted_line      0.966717      0.953850        0.967150  0.010996
# 2   elastic_transform      0.879383      0.874800        0.868033  0.013763
# 3                 fog      0.943617      0.943600        0.932583  0.052210
# 4       gaussian_blur      0.921167      0.933967        0.897550  0.031323
# 5      gaussian_noise      0.968783      0.958633        0.966600  0.010477
# 6       impulse_noise      0.961750      0.951100        0.964050  0.026886
# 7                line      0.872817      0.846300        0.866567  0.029544
# 8         motion_blur      0.949333      0.944317        0.928783  0.018960
# 9      pessimal_noise      0.931917      0.907717        0.934467  0.027588
# 10           pixelate      0.973450      0.971267        0.962283  0.006574
# 11         shot_noise      0.985217      0.977967        0.980467  0.005091
# 12            spatter      0.974050      0.968200        0.967133  0.012831
# 13             zigzag      0.907433      0.884033        0.905983  0.029015
# 14          zoom_blur      0.978300      0.977317        0.976983  0.005322
#
#      std_vgg  std_lcl16
# 0   0.012965   0.026948
# 1   0.013746   0.011321
# 2   0.017433   0.014595
# 3   0.051272   0.076182
# 4   0.024324   0.047306
# 5   0.013113   0.015840
# 6   0.020151   0.009853
# 7   0.023584   0.038234
# 8   0.016274   0.022933
# 9   0.030881   0.027466
# 10  0.009100   0.012796
# 11  0.009404   0.003985
# 12  0.013330   0.011477
# 13  0.031179   0.031136
# 14  0.005303   0.003894

# %%
from IPython.display import display, HTML
display(HTML("<style>.container { width:80% !important; }</style>"))
# Out:
# <style>.container { width:80% !important; }</style>

# %%
import matplotlib.pyplot as plt

plot_size = 5
fig, axs = plt.subplots(3,5, figsize=(5*plot_size,3*plot_size))

for y in range(5):
    for x in range(3):
        dfix = y+3*x
        row = dfx.iloc[dfix,:]
        df_i = df[df['mnist_c_variant'] == row['mnist_c']]
        
        vgg19 = df_i[df_i['experiment'] == 'VGG19']['accuracy'].to_numpy()
        vgg19lcl = df_i[df_i['experiment'] == 'VGG19+LCL']['accuracy'].to_numpy()
        vgg16lcl = df_i[df_i['experiment'] == 'VGG16+LCL']['accuracy'].to_numpy()
        
        axs[x,y].set_title(row['mnist_c'])
        axs[x,y].boxplot([vgg19lcl, vgg16lcl, vgg19])
        axs[x,y].set_xticklabels(['VGG19+LCL', 'VGG16+LCL', 'VGG19'])
        #axs[x,y].set_ylim([0.83, 1])
